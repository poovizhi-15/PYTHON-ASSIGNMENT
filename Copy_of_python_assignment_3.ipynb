# %% [markdown]
# <a href="https://colab.research.google.com/github/poovizhi-15/PYTHON-ASSIGNMENT/blob/main/Copy_of_python_assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **While Loop, For loop and Function**

# %% [markdown]
# **Number Guessing Game**

# %%
import random

# Generate random number between 1 and 10
secret_number = random.randint(1, 10)

# Maximum number of attempts
attempts = 3

print("Welcome to the Number Guessing Game!")
print("You have", attempts, "attempts to guess the correct number.")

# While loop for guessing
while attempts > 0:
    guess = int(input("Guess the number (between 1 and 10): "))

    # Check if guess is out of range
    if guess < 1 or guess > 10:
        print("Your guess is out of range. Please guess a number between 1 and 10.")
        continue

    # Check if guess is correct
    if guess == secret_number:
        print("Congratulations! You guessed the correct number.")
        break


    elif guess > secret_number:
        print("Too high. Try again.")


    else:
        print("Too low. Try again.")

    # Reduce attempts after valid guess
    attempts -= 1
    print("Attempts left:", attempts)


else:
    print("Better luck next time! The correct number was", secret_number)
# Out:
# Welcome to the Number Guessing Game!
# You have 3 attempts to guess the correct number.
# Guess the number (between 1 and 10): 2
# Too low. Try again.
# Attempts left: 2
# Guess the number (between 1 and 10): 15
# Your guess is out of range. Please guess a number between 1 and 10.
# Guess the number (between 1 and 10): 5
# Too high. Try again.
# Attempts left: 1
# Guess the number (between 1 and 10): 3
# Too low. Try again.
# Attempts left: 0
# Better luck next time! The correct number was 4

# %% [markdown]
# **For Loop:**

# %% [markdown]
# **Multiplication Table Generator**

# %%
number=int(input('Enter the number for which you want the multiplication table:'))
for i in range(1, 11):
    result = number * i
    print(number, "x", i, "=", result)
# Out:
# Enter the number for which you want the multiplication table:5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# **Function:**

# %% [markdown]
# **BMI Calculator**

# %%
def calculate_bmi(weight, height):
    bmi = weight / (height ** 2)
    return bmi
weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))
bmi_result = calculate_bmi(weight, height)
print("Your BMI is:", round(bmi_result, 2))
# Out:
# Enter your weight in kg: 49
# Enter your height in meters: 1.45
# Your BMI is: 23.31
