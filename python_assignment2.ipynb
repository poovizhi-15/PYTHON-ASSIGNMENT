# %% [markdown]
# <a href="https://colab.research.google.com/github/poovizhi-15/PYTHON-ASSIGNMENT/blob/main/python_assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Structures-List,Dictionary,Set & Conditional Statements**

# %% [markdown]
# **List (Creation, Modification and Access**):

# %% [markdown]
# 1. List Creation:

# %%
#a.Create age_list
age_list=[24,25,26,27,28]

# %%
#b.Create name_list
name_list=["Abi","Banu","chitra","Devi","Elan"]

# %% [markdown]
# 2. List Operations / Modifications:

# %%
# a.Append "Yazhini"
name_list.append("Yazhini")

# %%
# b.Insert element 30 at index 2
age_list.insert(2,30)

# %%
# c. Remove "Yazhini"
name_list.remove("Yazhini")

# %%
# d.Pop the last element from age_list
age_list.pop()
# Out:
# 28

# %%
# e.Extend the age_list
age_list.extend([29, 30, 26])

# %%
# f.Sort age_list in descending order
age_list.sort(reverse=True)

# %%
# g.Find Max age, Min age and sum of all ages from age_list.
max_age=max(age_list)
min_age=min(age_list)
sum_age=sum(age_list)
print("Age List:",age_list)
print("Max Age:",max_age)
print("Min Age:",min_age)
print("Sum of Ages:",sum_age)
# Out:
# Age List: [30, 27, 26, 25, 24, 29, 30, 26]
# Max Age: 30
# Min Age: 24
# Sum of Ages: 217

# %% [markdown]
# 3. Accessing List Elements:

# %%
# a.First Element
print("First name:",name_list[0])
# Out:
# First name: Abi

# %%
# b.Last Element
print("Last name:",name_list[-1])
# Out:
# Last name: Elan

# %%
#c. Print the elements from index 2 to index 4 in name_list.
print("Index 2 to 4:", name_list[2:5])
# Out:
# Index 2 to 4: ['chitra', 'Devi', 'Elan']

# %%
# d. Print the elements of name_list in reverse order.
print("Reversed List:", name_list[::-1])
# Out:
# Reversed List: ['Elan', 'Devi', 'chitra', 'Banu', 'Abi']

# %% [markdown]
# **Dictionary (Creation, Modification and Access)**:

# %%
# a. Create a dictionary named student_marks that maps the names of five
# students to their marks (use scale of from 0 to 100).

student_marks={
    "Abi":80,
    "Banu":75,
    "Chitra":60,
    "Devi":54,
    "Elan":95

}

# %%
# b. Access and print the mark of a specific student, of your choice.
print("Mark of Devi:",student_marks["Devi"])
# Out:
# Mark of Devi: 54

# %%
# c. Add a new student "Janani" with a mark of 80 to the student_marks dictionary.
student_marks["Janani"] = 80

# %%
# d. Update the mark of any one older student to 82.
student_marks["Abi"] = 82

# %%
# e. Use the keys(), values(), and items() methods to print all keys, values, and
# key-value pairs in the student_marks dictionary.

print("Keys:", student_marks.keys())
print("Values:", student_marks.values())
print("Items:", student_marks.items())
# Out:
# Keys: dict_keys(['Abi', 'Banu', 'Chitra', 'Devi', 'Elan', 'Janani'])
# Values: dict_values([82, 75, 60, 54, 95, 80])
# Items: dict_items([('Abi', 82), ('Banu', 75), ('Chitra', 60), ('Devi', 54), ('Elan', 95), ('Janani', 80)])

# %% [markdown]
# **Sets** (Operations):

# %%
#a. Create a set called my_set with following values:    ['a','e','i','o','u','a','a','i'] Analyse the output and provide explanation for the same.

my_set={'a','e','i','o','u','a','a','i'}
print(my_set)
# Out:
# {'a', 'e', 'i', 'o', 'u'}

# %%
# b. Attempt to change the value of my_set[4] = 's'. If code throws an error, provide an explanation.
my_set[4]='s'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2778587107.py in <cell line: 0>()
#       1 # b. Attempt to change the value of my_set[4] = 's'. If code throws an error, provide an explanation.
# ----> 2 my_set[4]='s'
#
# TypeError: 'set' object does not support item assignment

# %%
# c. Create two sets:  set1 with values: {1, 3, 5, 7, 9}  set2 with values: {2, 3, 5, 8, 10}

set1 = {1, 3, 5, 7, 9}
set2 = {2, 3, 5, 8, 10}

# %%
# d. Compute and print the union and intersection of set1 and set2.
print("Union:", set1.union(set2))
print("Intersection:", set1.intersection(set2))
# Out:
# Union: {1, 2, 3, 5, 7, 8, 9, 10}
# Intersection: {3, 5}

# %% [markdown]
# Operators & Conditional Statements :
# (IF, ELIF, ELSE)

# %%
# Performance Category Program:

score=int(input("Enter your score(0 to 10): "))
if score>7:
    print("Above Average: Excellent performance! keep it up.")
elif 4 <=score <=7:
    print("Average: Good effort! Keep practicing.")
else:
    print("Below Average: Need to improve your performance, consistent practice will lead to better results.")
# Out:
# Enter your score(0 to 10): 7
# Average: Good effort! Keep practicing.

# %% [markdown]
# # New section

# %% [markdown]
# # New section
